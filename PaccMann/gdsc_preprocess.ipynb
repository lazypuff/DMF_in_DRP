# %%
import pandas as pd
import os
import numpy as np
import random
from sklearn.model_selection import train_test_split

os.chdir('/nas/longleaf/home/qhz/paccmann_predictor/gdsc_old')
# Out:
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Response data; train and test

# %% [markdown]
# ### mask combination old gdsc

# %%
path = r'/nas/longleaf/home/qhz/paccmann_predictor/gdsc_old/mask_comb'

# %%
for i in range (10):
    maskcomb_train = pd.read_csv(f'{"mask_comb/train_cv"}_{i+1}.csv')
    maskcomb_train = maskcomb_train.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"}).drop(['Origin_idx'], axis=1)
    maskcomb_val = pd.read_csv(f'{"mask_comb/valid_cv"}_{i+1}.csv')
    maskcomb_val = maskcomb_val.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"}).drop(['Origin_idx'], axis=1)


    train_set, test_set = train_test_split(maskcomb_train, test_size=0.1, random_state=42)

    print(f"Fold {i + 1}: Train: {len(train_set)},Test: {len(test_set)}")

    
           
    train_set.to_csv(os.path.join(path, f'{"maskcomb_train"}_{i+1}.csv'))
    test_set.to_csv(os.path.join(path, f'{"maskcomb_test"}_{i+1}.csv'))
    maskcomb_val.to_csv(os.path.join(path, f'{"maskcomb_valid"}_{i+1}.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2779814/2079063861.py in <module>
#       1 for i in range (10):
# ----> 2     maskcomb_train = pd.read_csv(f'{"mask_comb/train_cv"}_{i+1}.csv')
#       3     maskcomb_train = maskcomb_train.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"}).drop(['Origin_idx'], axis=1)
#       4     maskcomb_val = pd.read_csv(f'{"mask_comb/valid_cv"}_{i+1}.csv')
#       5     maskcomb_val = maskcomb_val.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"}).drop(['Origin_idx'], axis=1)
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mask_comb/train_cv_1.csv'

# %%
for i in range (10):
    maskcomb_train = pd.read_csv(f'{"mask_comb/maskcomb_train"}_{i+1}.csv')
    maskcomb_test = pd.read_csv(f'{"mask_comb/maskcomb_test"}_{i+1}.csv')
    print(f"Fold {i + 1}: Train: {len(pd.unique(maskcomb_train['drug']))},Test: {len(pd.unique(maskcomb_test['drug']))}")
    print(f"Fold {i + 1}: Train: {len(pd.unique(maskcomb_train['drug']))},Test: {len(pd.unique(maskcomb_test['drug']))}")
# Out:
# Fold 1: Train: 144,Test: 135
# Fold 2: Train: 144,Test: 135
# Fold 3: Train: 144,Test: 136
# Fold 4: Train: 144,Test: 139
# Fold 5: Train: 144,Test: 141
# Fold 6: Train: 144,Test: 141
# Fold 7: Train: 144,Test: 141
# Fold 8: Train: 144,Test: 142
# Fold 9: Train: 144,Test: 143
# Fold 10: Train: 144,Test: 138

# %% [markdown]
# ### Mask cell, old gdsc dataset

# %%
path=r'/nas/longleaf/home/qhz/paccmann_predictor/gdsc_old/mask_cell'

# %%
for i in range (10):
    maskcell_train = pd.read_csv(f'{"mask_cell/train_cv"}_{i+1}.csv')
    maskcell_train = maskcell_train.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"}).drop(['Origin_idx'], axis=1)
    maskcell_val = pd.read_csv(f'{"mask_cell/valid_cv"}_{i+1}.csv')
    maskcell_val = maskcell_val.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"}).drop(['Origin_idx'], axis=1)

    cell_list = pd.unique(maskcell_train['cell_line'])

    train_cell, test_cell = train_test_split(cell_list, test_size=0.1, random_state=42)
    
    test_set = maskcell_train[maskcell_train['cell_line'].isin(test_cell)]
    train_set = maskcell_train[maskcell_train['cell_line'].isin(train_cell)]
       
    print(f"Fold {i + 1}: Train: {len(pd.unique(train_set['cell_line']))},Test: {len(pd.unique(test_set['cell_line']))}")
    
           
    train_set.to_csv(os.path.join(path, f'{"maskcell_train"}_{i+1}.csv'))
    test_set.to_csv(os.path.join(path, f'{"maskcell_test"}_{i+1}.csv'))
    maskcell_val.to_csv(os.path.join(path, f'{"maskcell_valid"}_{i+1}.csv'))
# Out:
# Fold 1: Train: 252,Test: 29
# Fold 2: Train: 252,Test: 29
# Fold 3: Train: 252,Test: 29
# Fold 4: Train: 252,Test: 29
# Fold 5: Train: 252,Test: 29
# Fold 6: Train: 252,Test: 29
# Fold 7: Train: 252,Test: 29
# Fold 8: Train: 252,Test: 29
# Fold 9: Train: 252,Test: 29
# Fold 10: Train: 251,Test: 28

# %% [markdown]
# ### Mask drug old gdsc

# %%
path=r'/nas/longleaf/home/qhz/paccmann_predictor/gdsc_old/mask_drug'

# %%
for i in range (10):
    maskdrug_train = pd.read_csv(f'{"mask_drug/train_cv"}_{i+1}.csv').drop(['Origin_idx'], axis=1)
    maskdrug_val = pd.read_csv(f'{"mask_drug/valid_cv"}_{i+1}.csv').drop(['Origin_idx'], axis=1)

    maskdrug_train = maskdrug_train.rename(columns={"Drug name": "drug", "Sanger ID": "cell_line"})
    maskdrug_val = maskdrug_val.rename(columns={ "Drug name": "drug", "Sanger ID": "cell_line"})

    drug_list = pd.unique(maskdrug_train['drug'])

    train_drug, test_drug = train_test_split(drug_list, test_size=0.1, random_state=42)
    
    train_set = maskdrug_train[maskdrug_train['drug'].isin(train_drug)]
    test_set = maskdrug_train[maskdrug_train['drug'].isin(test_drug)]
       
    print(f"Fold {i + 1}: Train: {len(pd.unique(train_set['drug']))},Test: {len(pd.unique(test_set['drug']))}")
    
           
    train_set.to_csv(os.path.join(path, f'{"maskdrug_train"}_{i+1}.csv'))
    test_set.to_csv(os.path.join(path, f'{"maskdrug_test"}_{i+1}.csv'))
    maskdrug_val.to_csv(os.path.join(path, f'{"maskdrug_valid"}_{i+1}.csv'))
# Out:
# Fold 1: Train: 117,Test: 13
# Fold 2: Train: 117,Test: 13
# Fold 3: Train: 117,Test: 13
# Fold 4: Train: 117,Test: 13
# Fold 5: Train: 117,Test: 13
# Fold 6: Train: 117,Test: 13
# Fold 7: Train: 117,Test: 13
# Fold 8: Train: 117,Test: 13
# Fold 9: Train: 117,Test: 13
# Fold 10: Train: 113,Test: 13

# %%
maskdrug_train_1 = pd.read_csv(f'{"mask_drug/train_cv"}_{1}.csv')
maskdrug_train_1
# Out:
#        Origin_idx   Drug name  Sanger ID      IC50
# 0           87440  Epirubicin  SIDM00565 -0.311385
# 1          222814       VE821  SIDM01090  3.110850
# 2           65099  Dinaciclib  SIDM00291 -2.624957
# 3          188256   Cediranib  SIDM00837  1.058220
# 4            7783  Vorinostat  SIDM01187  1.608329
# ...           ...         ...        ...       ...
# 32741      188220   Cediranib  SIDM00351  0.951231
# 32742      156075   Alisertib  SIDM00565  0.827024
# 32743      184226  Navitoclax  SIDM00234 -1.913660
# 32744      186132   Nilotinib  SIDM00257  2.158378
# 32745      117116      OTX015  SIDM01159  2.514232
#
# [32746 rows x 4 columns]

# %%
len(pd.unique(maskdrug_train_1['Drug name']))
# Out:
# 130

# %% [markdown]
# ## gene expression

# %%
import csv
gene_exp = pd.read_csv('gdsc_exp_common_forqh.csv')

# %%
df = gene_exp.drop(['Unnamed: 0', 'COSMIC_ID'], axis=1)

# %%
gene_exp.set_index(['SANGER_MODEL_ID'], inplace = True)
df = gene_exp

# %%
df
# Out:
#     SANGER_MODEL_ID    TSPAN6      TNMD       DPM1     SCYL3  C1orf112  \
# 0         SIDM00501  7.646494  2.626819  10.153853  3.564755  3.942749
# 1         SIDM00487  8.319417  3.111183   9.643558  4.757258  3.919757
# 2         SIDM00129  6.623308  3.077644  10.183766  4.058799  3.040080
# 3         SIDM00101  7.611268  2.704739  10.276079  3.650299  3.481567
# 4         SIDM00100  7.678658  2.845781  10.180954  3.573048  3.431235
# ..              ...       ...       ...        ...       ...       ...
# 307       SIDM00156  9.196714  2.798860  10.216423  4.385535  3.587151
# 308       SIDM00257  6.960437  3.107388  10.666876  3.804337  4.170327
# 309       SIDM00256  7.006548  2.651142   9.497497  4.284743  4.192037
# 310       SIDM00427  7.777379  3.357372  10.338039  3.882859  3.157759
# 311       SIDM00680  8.273418  2.702831   9.991126  4.246597  3.452435
#
#           FGR       CFH     FUCA2      GCLC  ...  LINC00526      PPY2  \
# 0    3.290760  3.551675  8.252413  5.831479  ...   4.800394  3.182512
# 1    3.602185  3.329644  9.076950  6.774675  ...   7.401823  3.621603
# 2    3.419085  3.499878  8.731266  4.725022  ...   4.372498  3.268263
# 3    3.145538  3.565127  7.861068  5.521610  ...   5.724560  3.153720
# 4    3.090781  4.116643  8.121190  5.757866  ...   3.819042  2.836544
# ..        ...       ...       ...       ...  ...        ...       ...
# 307  3.155066  3.540061  7.707727  6.708135  ...   6.261245  3.417083
# 308  2.929783  3.127463  3.505572  6.272051  ...   7.433085  3.085657
# 309  2.937278  3.333875  3.091999  5.111579  ...   7.519826  3.095171
# 310  3.219952  5.978931  3.674984  5.691279  ...   4.524538  2.976009
# 311  3.359665  3.160107  8.783047  6.784364  ...   5.294721  3.118763
#
#      Var.17731  Var.17732  KRT18P55  Var.17734  POLRMTP1     UBL5P2  TBC1D3P5  \
# 0     3.031739   7.850447  3.017795   3.123141  3.227523   9.170450  3.489892
# 1     3.085394   9.184980  2.913459   3.828827  3.461608   9.191528  3.286008
# 2     3.068514   8.747241  2.801401   2.952522  3.976208  10.200381  3.459678
# 3     3.023024   8.166334  3.107518   3.008081  2.829701   8.873518  3.426125
# 4     2.886952   8.952158  3.388515   2.894347  3.139998   9.497852  3.023315
# ..         ...        ...       ...        ...       ...        ...       ...
# 307   3.011904   9.201191  3.342835   3.153633  2.914752   9.146660  3.560097
# 308   3.013138   9.656800  3.214995   3.210881  3.380043   9.164155  3.334526
# 309   3.180082   8.620281  3.032564   3.708400  3.166274   9.007112  3.636103
# 310   2.987950   9.318264  3.167713   3.525738  3.326836   9.365589  3.166035
# 311   3.126184   8.415219  3.251545   3.138742  2.982887   8.147107  3.331601
#
#      Var.17738
# 0     6.911407
# 1     7.484771
# 2     7.876285
# 3     8.514814
# 4     7.789742
# ..         ...
# 307   7.719213
# 308   8.208055
# 309   7.074198
# 310   7.789513
# 311   7.236222
#
# [312 rows x 17738 columns]

# %%
df.to_csv('gdsc_gene_exp.csv',index=False)

# %% [markdown]
# # Smiles

# %%
ccle_drug = list(ccle_smile['drug'])
ccle_smiles = list(ccle_smile['canonical_smiles'])
gdsc_drug = list(gdsc_smile['drug'])
gdsc_smiles = list(gdsc_smile['canonical_smiles'])

# %%
random.shuffle(ccle_drug)
ccle_random_smile = pd.DataFrame(zip(ccle_smiles,ccle_drug),columns = ['canonical_smiles','drug']) 
random.shuffle(gdsc_drug)
gdsc_random_smile = pd.DataFrame(zip(gdsc_smiles,gdsc_drug),columns = ['canonical_smiles','drug'])

# %%
np.savetxt(r'ccle_smile_random.txt', ccle_random_smile, fmt='%s', delimiter='\t')
np.savetxt(r'gdsc_smile_random.txt', gdsc_random_smile, fmt='%s', delimiter='\t')

# %% [markdown]
# ### New GDSC smiles

# %%
import pandas as pd
import numpy as np
import requests
from itertools import product
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
def smiles_from_pubchem_cids(cids):

    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{','.join(map(str, cids))}/property/CanonicalSMILES/JSON"
    r = requests.get(url)
    r.raise_for_status()
    return [item["CanonicalSMILES"] for item in r.json()["PropertyTable"]["Properties"]]

# %%
druginfos = pd.read_csv('oldGDSC_druginfo.csv')

# %%
druginfos['smiles'] = smiles_from_pubchem_cids(druginfos['cid'])
druginfos
# Out:
#      Unnamed: 0       cid     drug_name  \
# 0             0     24360  Camptothecin
# 1             1     13342   Vinblastine
# 2             2   5702198     Cisplatin
# 3             3      6253    Cytarabine
# 4             4    148124     Docetaxel
# ..          ...       ...           ...
# 139         139  51000408         VE821
# 140         140  44137675       AZD6482
# 141         141  24905401       AT13148
# 142         142  24785538    BMS-754807
# 143         143  46907787           JQ1
#
#                                                 smiles
# 0    CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 1    CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...
# 2                                         N.N.Cl[Pt]Cl
# 3                   C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)O
# 4    CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...
# ..                                                 ...
# 139  CS(=O)(=O)C1=CC=C(C=C1)C2=CN=C(C(=N2)C(=O)NC3=...
# 140  CC1=CN2C(=O)C=C(N=C2C(=C1)C(C)NC3=CC=CC=C3C(=O...
# 141      C1=CC(=CC=C1C2=CNN=C2)C(CN)(C3=CC=C(C=C3)Cl)O
# 142  CC1(CCCN1C2=NN3C=CC=C3C(=N2)NC4=NNC(=C4)C5CC5)...
# 143  CC1=C(SC2=C1C(=NC(C3=NN=C(N32)C)CC(=O)OC(C)(C)...
#
# [144 rows x 4 columns]

# %%
data = {"canonical_smiles" : druginfos['smiles'], "drug": druginfos['drug_name']}
df = pd.DataFrame(data)
df
# Out:
#                                       canonical_smiles          drug
# 0    CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...  Camptothecin
# 1    CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...   Vinblastine
# 2                                         N.N.Cl[Pt]Cl     Cisplatin
# 3                   C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)O    Cytarabine
# 4    CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...     Docetaxel
# ..                                                 ...           ...
# 139  CS(=O)(=O)C1=CC=C(C=C1)C2=CN=C(C(=N2)C(=O)NC3=...         VE821
# 140  CC1=CN2C(=O)C=C(N=C2C(=C1)C(C)NC3=CC=CC=C3C(=O...       AZD6482
# 141      C1=CC(=CC=C1C2=CNN=C2)C(CN)(C3=CC=C(C=C3)Cl)O       AT13148
# 142  CC1(CCCN1C2=NN3C=CC=C3C(=N2)NC4=NNC(=C4)C5CC5)...    BMS-754807
# 143  CC1=C(SC2=C1C(=NC(C3=NN=C(N32)C)CC(=O)OC(C)(C)...           JQ1
#
# [144 rows x 2 columns]

# %%
np.savetxt(r'gdsc_smile.txt', df, fmt='%s', delimiter='\t')

# %%
import random
drug_list = df['drug']
random.seed(316)
shuff_list = random.Random(316).shuffle(drug_list)
shuff_list = drug_list
shuff_list
# Out:
# 0      Temozolomide
# 1             VE821
# 2       Talazoparib
# 3            VX-11e
# 4          PD173074
#            ...
# 139           AZ960
# 140       Cisplatin
# 141          LGK974
# 142      Cytarabine
# 143      Navitoclax
# Name: drug, Length: 144, dtype: object

# %%
shuf_smiles =  pd.DataFrame(data = { "canonical_smiles": df['canonical_smiles'],"drug": shuff_list})

# %%
shuf_smiles
# Out:
#                                       canonical_smiles          drug
# 0    CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...  Temozolomide
# 1    CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...         VE821
# 2                                         N.N.Cl[Pt]Cl   Talazoparib
# 3                   C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)O        VX-11e
# 4    CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...      PD173074
# ..                                                 ...           ...
# 139  CS(=O)(=O)C1=CC=C(C=C1)C2=CN=C(C(=N2)C(=O)NC3=...         AZ960
# 140  CC1=CN2C(=O)C=C(N=C2C(=C1)C(C)NC3=CC=CC=C3C(=O...     Cisplatin
# 141      C1=CC(=CC=C1C2=CNN=C2)C(CN)(C3=CC=C(C=C3)Cl)O        LGK974
# 142  CC1(CCCN1C2=NN3C=CC=C3C(=N2)NC4=NNC(=C4)C5CC5)...    Cytarabine
# 143  CC1=C(SC2=C1C(=NC(C3=NN=C(N32)C)CC(=O)OC(C)(C)...    Navitoclax
#
# [144 rows x 2 columns]

# %%
drug_list = df['drug']

# %%
np.savetxt(r'gdsc_smile_random.txt', shuf_smiles, fmt='%s', delimiter='\t')

# %% [markdown]
# median iqr wilcoxon2sample
